# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

import os
from scipy.sparse import coo_matrix

# %%
train_data = pd.read_csv('amazon.csv')
train_data.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
train_data = train_data[['product_id', 'product_name', 'category', 'discounted_price',
       'actual_price', 'discount_percentage', 'rating', 'rating_count', 
       'img_link', 'product_link']]
train_data.head(3)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...

# %%
train_data.shape
# Out:
# (1465, 10)

# %%
train_data.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# img_link               0
# product_link           0
# dtype: int64

# %%
train_data['rating_count'].fillna(0, inplace=True)
# Out:
# C:\Users\ggurk\AppData\Local\Temp\ipykernel_4352\3425262430.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data['rating_count'].fillna(0, inplace=True)

# %%
train_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
train_data['id'] = range(1, len(train_data) + 1)
train_data.head(3)
# Out:
#    id  product_id                                       product_name  \
# 0   1  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1   2  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2   3  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...

# %%
# Convert product_id to numeric by extracting digits and store in a new DataFrame
train_data_numeric_id = train_data.copy()
train_data_numeric_id['product_id_numeric'] = train_data_numeric_id['product_id'].str.extract(r'(\d+)').astype(float)
train_data_numeric_id.head(3)
# Out:
#    id  product_id                                       product_name  \
# 0   1  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1   2  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2   3  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link  product_id_numeric
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...                 7.0
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...                98.0
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...                96.0

# %%
def alphanum_to_digit(s):
      mapping = {chr(i): str((i - ord('a')) % 10) for i in range(ord('a'), ord('z') + 1)}
      mapping.update({chr(i): str((i - ord('A')) % 10) for i in range(ord('A'), ord('Z') + 1)})
      result = ''.join([mapping.get(ch, ch) for ch in s])
      return float(result)

train_data_numeric_id['product_id_numeric'] = train_data_numeric_id['product_id'].apply(alphanum_to_digit)
train_data_numeric_id.head(3)
# Out:
#    id  product_id                                       product_name  \
# 0   1  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1   2  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2   3  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link  product_id_numeric
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...        1.079297e+09
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...        1.098387e+09
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...        1.096283e+09

# %%
train_data_numeric_id['product_id_numeric'] = train_data_numeric_id['product_id_numeric'].apply(lambda x: float(str(x).replace('0', '')))
train_data_numeric_id.head(3)
# Out:
#    id  product_id                                       product_name  \
# 0   1  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1   2  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2   3  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link  product_id_numeric
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...         179297491.0
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...         198386516.0
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...         196282629.0

# %%
train_data['product_id'] = train_data_numeric_id['product_id_numeric']
train_data.head(3)
# Out:
#    id   product_id                                       product_name  \
# 0   1  179297491.0  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1   2  198386516.0  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2   3  196282629.0  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
